# %%
# loading needed methods
import warnings
warnings.filterwarnings("ignore")


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.cm as cm

from scipy.fft import fft,dst
from random import seed,sample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score, roc_curve, auc,\
precision_score
import tensorflow.keras as keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

# %%
dataset = pd.read_csv('../input/Fraud/backup.csv') # unchanged dataset1

# %%
dataset = dataset.drop('Unnamed: 0', axis = 1)
dataset = pd.get_dummies(dataset,prefix=['type'])

# %%
len(dataset[dataset['isFraud']==1])
# Out:
# 8213

# %%
X = dataset.drop("isFraud",1)
y = dataset.isFraud

# %%
X
# Out:
#          step      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0           1      181.00         181.00             0.0            0.00
# 1           1      181.00         181.00             0.0        21182.00
# 2           1   229133.94       15325.00             0.0         5083.00
# 3           1   215310.30         705.00             0.0        22425.00
# 4           1   311685.89       10835.00             0.0         6267.00
# ...       ...         ...            ...             ...             ...
# 2770404   743   339682.13      339682.13             0.0            0.00
# 2770405   743  6311409.28     6311409.28             0.0            0.00
# 2770406   743  6311409.28     6311409.28             0.0        68488.84
# 2770407   743   850002.52      850002.52             0.0            0.00
# 2770408   743   850002.52      850002.52             0.0      6510099.11
#
#          newbalanceDest  errorBalanceOrg  errorBalanceDest  HourOfDay  \
# 0                  0.00             0.00      1.810000e+02          1
# 1                  0.00             0.00      2.136300e+04          1
# 2              51513.44        213808.94      1.827035e+05          1
# 3                  0.00        214605.30      2.377353e+05          1
# 4            2719172.89        300850.89     -2.401220e+06          1
# ...                 ...              ...               ...        ...
# 2770404       339682.13             0.00      0.000000e+00         23
# 2770405            0.00             0.00      6.311409e+06         23
# 2770406      6379898.11             0.00      1.000000e-02         23
# 2770407            0.00             0.00      8.500025e+05         23
# 2770408      7360101.63             0.00      9.313226e-10         23
#
#          type_CASH_OUT  type_TRANSFER
# 0                    0              1
# 1                    1              0
# 2                    1              0
# 3                    0              1
# 4                    0              1
# ...                ...            ...
# 2770404              1              0
# 2770405              0              1
# 2770406              1              0
# 2770407              0              1
# 2770408              1              0
#
# [2770409 rows x 11 columns]

# %%
yf = dst(X, type=2, norm='ortho')

# %%
# rad = yf@yf.T

# %%
yf=pd.DataFrame(np.abs(yf))
yf['isFraud']=y

# %%
# yf.to_csv('Xdst.csv', encoding='utf-8', index = 'false')

# %%
def preprocess_data(df):
    class0_df = df[df['isFraud'] == 0] ## majority class, will be used for autoencoder training
    class1_df = df[df['isFraud'] == 1]
    ##
    class0_arr = np.array(class0_df.drop('isFraud',axis = 1)) 
    class1_arr = np.array(class1_df.drop('isFraud',axis = 1))
    X = class0_arr
    X_train, X_test = train_test_split(X, test_size=0.3)
    X_train, X_val = train_test_split(X_train, test_size=0.1)
    
    print("====><>>>>>")
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    X_val = scaler.transform(X_val)
    return X_train, X_val, X_test, class1_arr

# %%
X_train, X_val, X_test, class1_arr = preprocess_data(yf)
n_features = X_train.shape[1]
# Out:
# ====><>>>>>

# %%
n_features
# Out:
# 11

# %%
print("Train Size: {}".format(len(X_train)))
print("Val Size: {}".format(len(X_val)))
print("Test Size: {}".format(len(X_test)))
print("No of Features: {}".format(n_features))
# Out:
# Train Size: 1740183
# Val Size: 193354
# Test Size: 828659
# No of Features: 11

# %%
len(class1_arr)
# Out:
# 8213

# %%
# model archticeture

def build_model():
    model = keras.Sequential([
        keras.Input(shape=(n_features,)),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(32, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(16, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(32, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(64, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(n_features)
    ])
    
    return model

# %%
# model building
model = build_model()

# %%
# model compile
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),
              loss='mse', metrics=['accuracy'])

# %%
# callbacks defined

# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.5
    epochs_drop = 5
    lrate = initial_lrate * (drop**((1 + epoch)/epochs_drop))
    return lrate

lrate_scheduler = LearningRateScheduler(step_decay)
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model_chkpoint = ModelCheckpoint('best_model_dst.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# model fitting
model.fit(X_train, X_train, batch_size=512, epochs=10, validation_data=(X_val, X_val), callbacks=[early_stop, model_chkpoint, lrate_scheduler])
# Out:
# Train on 1740183 samples, validate on 193354 samples
# Epoch 1/10
# 1739264/1740183 [============================>.] - ETA: 0s - loss: 0.0996 - accuracy: 0.5515
# Epoch 00001: val_loss improved from inf to 0.02925, saving model to best_model_dst.h5
# 1740183/1740183 [==============================] - 57s 33us/sample - loss: 0.0996 - accuracy: 0.5516 - val_loss: 0.0292 - val_accuracy: 0.4696
# Epoch 2/10
# 1738240/1740183 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.6557
# Epoch 00002: val_loss improved from 0.02925 to 0.02657, saving model to best_model_dst.h5
# 1740183/1740183 [==============================] - 52s 30us/sample - loss: 0.0264 - accuracy: 0.6558 - val_loss: 0.0266 - val_accuracy: 0.4374
# Epoch 3/10
# 1739776/1740183 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.6708
# Epoch 00003: val_loss improved from 0.02657 to 0.02656, saving model to best_model_dst.h5
# 1740183/1740183 [==============================] - 52s 30us/sample - loss: 0.0196 - accuracy: 0.6708 - val_loss: 0.0266 - val_accuracy: 0.4885
# Epoch 4/10
# 1738752/1740183 [============================>.] - ETA: 0s - loss: 0.0150 - accuracy: 0.6863
# Epoch 00004: val_loss improved from 0.02656 to 0.01322, saving model to best_model_dst.h5
# 1740183/1740183 [==============================] - 43s 25us/sample - loss: 0.0150 - accuracy: 0.6862 - val_loss: 0.0132 - val_accuracy: 0.4633
# Epoch 5/10
# 1739264/1740183 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.6996
# Epoch 00005: val_loss improved from 0.01322 to 0.01017, saving model to best_model_dst.h5
# 1740183/1740183 [==============================] - 39s 22us/sample - loss: 0.0127 - accuracy: 0.6996 - val_loss: 0.0102 - val_accuracy: 0.5502
# Epoch 6/10
# 1738752/1740183 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.7075
# Epoch 00006: val_loss did not improve from 0.01017
# 1740183/1740183 [==============================] - 36s 21us/sample - loss: 0.0117 - accuracy: 0.7074 - val_loss: 0.0179 - val_accuracy: 0.4867
# Epoch 7/10
# 1739264/1740183 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.7185
# Epoch 00007: val_loss did not improve from 0.01017
# 1740183/1740183 [==============================] - 46s 27us/sample - loss: 0.0100 - accuracy: 0.7185 - val_loss: 0.0208 - val_accuracy: 0.4417
# Epoch 8/10
# 1738752/1740183 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.7270
# Epoch 00008: val_loss did not improve from 0.01017
# 1740183/1740183 [==============================] - 44s 25us/sample - loss: 0.0089 - accuracy: 0.7270 - val_loss: 0.0329 - val_accuracy: 0.3739
# Epoch 9/10
# 1739264/1740183 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.7315
# Epoch 00009: val_loss did not improve from 0.01017
# 1740183/1740183 [==============================] - 53s 31us/sample - loss: 0.0083 - accuracy: 0.7315 - val_loss: 0.0136 - val_accuracy: 0.5285
# Epoch 10/10
# 1738752/1740183 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.7344
# Epoch 00010: val_loss did not improve from 0.01017
# 1740183/1740183 [==============================] - 49s 28us/sample - loss: 0.0076 - accuracy: 0.7344 - val_loss: 0.0181 - val_accuracy: 0.5046
# Epoch 00010: early stopping

# %%
def rel(y_test,y_pred):
    predictionsRFR=np.array(y_pred,dtype='int') 
    CM_RFR = confusion_matrix(y_test,predictionsRFR)
    CR_RFR = classification_report(y_test,predictionsRFR)
    fprRFR, recallRFR, thresholdsRFR = roc_curve(y_test, predictionsRFR)
    AUC_RFR = auc(fprRFR, recallRFR)
    print("=============<>==================\n")
    resultsRFR = {"Confusion Matrix":CM_RFR,"Classification Report":CR_RFR,"Area Under Curve":AUC_RFR}
    for measure in resultsRFR:
        print(measure,": \n",resultsRFR[measure])
    print("=============<>==================\n")

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
from sklearn.metrics import precision_recall_curve, roc_curve


def reconstruction_error(actual, pred):
    return np.mean((actual - pred)**2, axis=1)

def evaluate(model, X, y):
    X = X.reshape(-1, n_features)
    out = reconstruction_error(X, model.predict(X))
    print("AUC score: {}".format(roc_auc_score(y, out)))
    print("PR score: {}".format(average_precision_score(y, out)))
    print("\n\n")
    for th in [0.5, 0.6, 0.7, 0.8, 0.9, 1., 1.1 , 1.2, 1.3, 1.4, 1.5, 1.75, 2, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]:
        out_th = [1 if (o > th) else 0 for o in out]
        print("TH - {}".format(th))
        print("Precision: {}".format(precision_score(y, out_th)))
        print("Recall: {}".format(recall_score(y, out_th)))
        print("F1score: {}".format(f1_score(y, out_th)))
        rel(y,out_th)
        print("\n\n")

# %%
final_X_test = np.concatenate((X_test, class1_arr))
final_Y_test = np.concatenate(([0]*len(X_test), [1]*len(class1_arr)))

# %%
# Metrics
evaluate(model, final_X_test, final_Y_test)
# Out:
# AUC score: 1.0
# PR score: 1.0
#
#
#
# TH - 0.5
# Precision: 0.7781883646010991
# Recall: 1.0
# F1score: 0.8752597644802046
# =============<>==================
#
# Confusion Matrix :
#  [[826318   2341]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.78      1.00      0.88      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.89      1.00      0.94    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9985874768752889
# =============<>==================
#
#
#
#
# TH - 0.6
# Precision: 0.8324548956010541
# Recall: 1.0
# F1score: 0.9085679517672438
# =============<>==================
#
# Confusion Matrix :
#  [[827006   1653]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.83      1.00      0.91      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.92      1.00      0.95    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9990026054142898
# =============<>==================
#
#
#
#
# TH - 0.7
# Precision: 0.8718683651804671
# Recall: 1.0
# F1score: 0.9315488005444337
# =============<>==================
#
# Confusion Matrix :
#  [[827452   1207]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.87      1.00      0.93      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.94      1.00      0.97    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9992717149032353
# =============<>==================
#
#
#
#
# TH - 0.8
# Precision: 0.8994633665534991
# Recall: 1.0
# F1score: 0.9470710332103321
# =============<>==================
#
# Confusion Matrix :
#  [[827741    918]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.90      1.00      0.95      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.95      1.00      0.97    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9994460930249959
# =============<>==================
#
#
#
#
# TH - 0.9
# Precision: 0.9110371602884082
# Recall: 1.0
# F1score: 0.9534478755514278
# =============<>==================
#
# Confusion Matrix :
#  [[827857    802]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.91      1.00      0.95      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.96      1.00      0.98    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9995160856275017
# =============<>==================
#
#
#
#
# TH - 1.0
# Precision: 0.9214630315269831
# Recall: 1.0
# F1score: 0.9591264743664604
# =============<>==================
#
# Confusion Matrix :
#  [[827959    700]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.92      1.00      0.96      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.96      1.00      0.98    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9995776308469466
# =============<>==================
#
#
#
#
# TH - 1.1
# Precision: 0.9297034186099162
# Recall: 1.0
# F1score: 0.9635713028685399
# =============<>==================
#
# Confusion Matrix :
#  [[828038    621]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.93      1.00      0.96      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.96      1.00      0.98    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9996252982227913
# =============<>==================
#
#
#
#
# TH - 1.2
# Precision: 0.9360610895828585
# Recall: 1.0
# F1score: 0.9669747453935362
# =============<>==================
#
# Confusion Matrix :
#  [[828098    561]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.94      1.00      0.97      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.97      1.00      0.98    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.999661501293053
# =============<>==================
#
#
#
#
# TH - 1.3
# Precision: 0.94077892325315
# Recall: 1.0
# F1score: 0.9694859233901907
# =============<>==================
#
# Confusion Matrix :
#  [[828142    517]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.94      1.00      0.97      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.97      1.00      0.98    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9996880502112448
# =============<>==================
#
#
#
#
# TH - 1.4
# Precision: 0.9443486259629758
# Recall: 1.0
# F1score: 0.971377882909521
# =============<>==================
#
# Confusion Matrix :
#  [[828175    484]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.94      1.00      0.97      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.97      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9997079618998889
# =============<>==================
#
#
#
#
# TH - 1.5
# Precision: 0.9468526631311966
# Recall: 1.0
# F1score: 0.9727008941789542
# =============<>==================
#
# Confusion Matrix :
#  [[828198    461]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.95      1.00      0.97      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.97      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9997218397434892
# =============<>==================
#
#
#
#
# TH - 1.75
# Precision: 0.9530053376653516
# Recall: 1.0
# F1score: 0.9759372586299091
# =============<>==================
#
# Confusion Matrix :
#  [[828254    405]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.95      1.00      0.98      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.98      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9997556292757335
# =============<>==================
#
#
#
#
# TH - 2
# Precision: 0.9568915297681463
# Recall: 1.0
# F1score: 0.9779709454632054
# =============<>==================
#
# Confusion Matrix :
#  [[828289    370]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.96      1.00      0.98      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.98      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9997767477333861
# =============<>==================
#
#
#
#
# TH - 2.5
# Precision: 0.9640802911139805
# Recall: 1.0
# F1score: 0.9817116901745159
# =============<>==================
#
# Confusion Matrix :
#  [[828353    306]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.96      1.00      0.98      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.98      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9998153643416653
# =============<>==================
#
#
#
#
# TH - 2.75
# Precision: 0.9674873365531865
# Recall: 1.0
# F1score: 0.9834750329301881
# =============<>==================
#
# Confusion Matrix :
#  [[828383    276]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.97      1.00      0.98      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.98      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9998334658767961
# =============<>==================
#
#
#
#
# TH - 3
# Precision: 0.968171637392432
# Recall: 1.0
# F1score: 0.9838284619070435
# =============<>==================
#
# Confusion Matrix :
#  [[828389    270]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.97      1.00      0.98      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.98      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9998370861838223
# =============<>==================
#
#
#
#
# TH - 3.25
# Precision: 0.970115757146232
# Recall: 1.0
# F1score: 0.9848312248935788
# =============<>==================
#
# Confusion Matrix :
#  [[828406    253]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.97      1.00      0.98      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.99      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9998473437203965
# =============<>==================
#
#
#
#
# TH - 3.5
# Precision: 0.971377882909521
# Recall: 1.0
# F1score: 0.9854811615070794
# =============<>==================
#
# Confusion Matrix :
#  [[828417    242]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.97      1.00      0.99      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.99      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9998539809499445
# =============<>==================
#
#
#
#
# TH - 3.75
# Precision: 0.9727584981641597
# Recall: 1.0
# F1score: 0.9861911623439001
# =============<>==================
#
# Confusion Matrix :
#  [[828429    230]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.97      1.00      0.99      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.99      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.9998612215639967
# =============<>==================
#
#
#
#
# TH - 4
# Precision: 0.9737965378230969
# Recall: 1.0
# F1score: 0.9867243347149637
# =============<>==================
#
# Confusion Matrix :
#  [[828438    221]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    828659
#            1       0.97      1.00      0.99      8213
#
#     accuracy                           1.00    836872
#    macro avg       0.99      1.00      0.99    836872
# weighted avg       1.00      1.00      1.00    836872
#
# Area Under Curve :
#  0.999866652024536
# =============<>==================
