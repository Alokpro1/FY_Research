# %%
# loading needed methods
import warnings
warnings.filterwarnings("ignore")


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.cm as cm

from scipy.fft import fft, fftfreq, fftshift
from random import seed,sample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score, roc_curve, auc,\
precision_score
import tensorflow.keras as keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

# %%
dataset = pd.read_csv('../input/Fraud/backup.csv') # unchanged dataset1

# %%
dataset = dataset.drop('Unnamed: 0', axis = 1)
dataset = pd.get_dummies(dataset,prefix=['type'])

# %%
len(dataset[dataset['isFraud']==1])
# Out:
# 8213

# %%
X = dataset.drop("isFraud",1)
y = dataset.isFraud

# %%
yf = fft(X)

# %%
yf=pd.DataFrame(np.abs(yf))
yf['isFraud']=y

# %%
yf.to_csv('Xfft.csv', encoding='utf-8', index = 'false')

# %%
def preprocess_data(df):
    class0_df = df[df['isFraud'] == 0] ## majority class, will be used for autoencoder training
    class1_df = df[df['isFraud'] == 1]
    ##
    class0_arr = np.array(class0_df.drop('isFraud',axis = 1)) 
    class1_arr = np.array(class1_df.drop('isFraud',axis = 1))
    X = class0_arr
    X_train, X_test = train_test_split(X, test_size=0.1)
    X_train, X_val = train_test_split(X_train, test_size=0.1)
    
    print("====><>>>>>")
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    X_val = scaler.transform(X_val)
    return X_train, X_val, X_test, class1_arr

# %%
X_train, X_val, X_test, class1_arr = preprocess_data(yf)
n_features = X_train.shape[1]
# Out:
# ====><>>>>>

# %%
n_features
# Out:
# 11

# %%
print("Train Size: {}".format(len(X_train)))
print("Val Size: {}".format(len(X_val)))
print("Test Size: {}".format(len(X_test)))
print("No of Features: {}".format(n_features))
# Out:
# Train Size: 2237378
# Val Size: 248598
# Test Size: 276220
# No of Features: 11

# %%
len(class1_arr)
# Out:
# 8213

# %%
# model archticeture

def build_model():
    model = keras.Sequential([
        keras.Input(shape=(n_features,)),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(32, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(16, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(32, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(64, activation='relu'),
        keras.layers.BatchNormalization(),
        
        keras.layers.Dense(n_features)
    ])
    
    return model

# %%
# model building
model = build_model()

# %%
# model compile
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),
              loss='mse', metrics=['accuracy'])

# %%
# callbacks defined

# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.5
    epochs_drop = 5
    lrate = initial_lrate * (drop**((1 + epoch)/epochs_drop))
    return lrate

lrate_scheduler = LearningRateScheduler(step_decay)
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model_chkpoint = ModelCheckpoint('best_model_fft.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# model fitting
model.fit(X_train, X_train, batch_size=512, epochs=10, validation_data=(X_val, X_val), callbacks=[early_stop, model_chkpoint, lrate_scheduler])
# Out:
# Train on 2237378 samples, validate on 248598 samples
# Epoch 1/10
# 2236928/2237378 [============================>.] - ETA: 0s - loss: 0.0707 - accuracy: 0.2618
# Epoch 00001: val_loss improved from inf to 0.02701, saving model to best_model_fft.h5
# 2237378/2237378 [==============================] - 77s 34us/sample - loss: 0.0707 - accuracy: 0.2619 - val_loss: 0.0270 - val_accuracy: 0.2801
# Epoch 2/10
# 2236928/2237378 [============================>.] - ETA: 0s - loss: 0.0199 - accuracy: 0.3213
# Epoch 00002: val_loss did not improve from 0.02701
# 2237378/2237378 [==============================] - 79s 35us/sample - loss: 0.0199 - accuracy: 0.3213 - val_loss: 0.0278 - val_accuracy: 0.1412
# Epoch 3/10
# 2236416/2237378 [============================>.] - ETA: 0s - loss: 0.0140 - accuracy: 0.3502
# Epoch 00003: val_loss did not improve from 0.02701
# 2237378/2237378 [==============================] - 79s 35us/sample - loss: 0.0140 - accuracy: 0.3502 - val_loss: 0.0274 - val_accuracy: 0.2861
# Epoch 4/10
# 2236928/2237378 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.3735
# Epoch 00004: val_loss improved from 0.02701 to 0.02467, saving model to best_model_fft.h5
# 2237378/2237378 [==============================] - 69s 31us/sample - loss: 0.0104 - accuracy: 0.3735 - val_loss: 0.0247 - val_accuracy: 0.2406
# Epoch 5/10
# 2236928/2237378 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.3960
# Epoch 00005: val_loss improved from 0.02467 to 0.00919, saving model to best_model_fft.h5
# 2237378/2237378 [==============================] - 73s 32us/sample - loss: 0.0084 - accuracy: 0.3960 - val_loss: 0.0092 - val_accuracy: 0.2704
# Epoch 6/10
# 2236928/2237378 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.4075
# Epoch 00006: val_loss did not improve from 0.00919
# 2237378/2237378 [==============================] - 80s 36us/sample - loss: 0.0074 - accuracy: 0.4075 - val_loss: 0.0188 - val_accuracy: 0.2972
# Epoch 7/10
# 2235904/2237378 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.4130
# Epoch 00007: val_loss improved from 0.00919 to 0.00804, saving model to best_model_fft.h5
# 2237378/2237378 [==============================] - 59s 26us/sample - loss: 0.0066 - accuracy: 0.4130 - val_loss: 0.0080 - val_accuracy: 0.3013
# Epoch 8/10
# 2236928/2237378 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.4222
# Epoch 00008: val_loss did not improve from 0.00804
# 2237378/2237378 [==============================] - 60s 27us/sample - loss: 0.0058 - accuracy: 0.4222 - val_loss: 0.0181 - val_accuracy: 0.2432
# Epoch 9/10
# 2235392/2237378 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.4242
# Epoch 00009: val_loss did not improve from 0.00804
# 2237378/2237378 [==============================] - 52s 23us/sample - loss: 0.0053 - accuracy: 0.4242 - val_loss: 0.0281 - val_accuracy: 0.4040
# Epoch 10/10
# 2235392/2237378 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.4260
# Epoch 00010: val_loss did not improve from 0.00804
# 2237378/2237378 [==============================] - 56s 25us/sample - loss: 0.0047 - accuracy: 0.4260 - val_loss: 0.0187 - val_accuracy: 0.3823

# %%
def rel(y_test,y_pred):
    predictionsRFR=np.array(y_pred,dtype='int') 
    CM_RFR = confusion_matrix(y_test,predictionsRFR)
    CR_RFR = classification_report(y_test,predictionsRFR)
    fprRFR, recallRFR, thresholdsRFR = roc_curve(y_test, predictionsRFR)
    AUC_RFR = auc(fprRFR, recallRFR)
    print("=============<>==================\n")
    resultsRFR = {"Confusion Matrix":CM_RFR,"Classification Report":CR_RFR,"Area Under Curve":AUC_RFR}
    for measure in resultsRFR:
        print(measure,": \n",resultsRFR[measure])
    print("=============<>==================\n")

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
from sklearn.metrics import precision_recall_curve, roc_curve


def reconstruction_error(actual, pred):
    return np.mean((actual - pred)**2, axis=1)

def evaluate(model, X, y):
    X = X.reshape(-1, n_features)
    out = reconstruction_error(X, model.predict(X))
    print("AUC score: {}".format(roc_auc_score(y, out)))
    print("PR score: {}".format(average_precision_score(y, out)))
    print("\n\n")
    for th in [0.5, 0.6, 0.7, 0.8, 0.9, 1., 1.1 , 1.2, 1.3, 1.4, 1.5, 1.75, 2, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]:
        out_th = [1 if (o > th) else 0 for o in out]
        print("TH - {}".format(th))
        print("Precision: {}".format(precision_score(y, out_th)))
        print("Recall: {}".format(recall_score(y, out_th)))
        print("F1score: {}".format(f1_score(y, out_th)))
        rel(y,out_th)
        print("\n\n")

# %%
final_X_test = np.concatenate((X_test, class1_arr))
final_Y_test = np.concatenate(([0]*len(X_test), [1]*len(class1_arr)))375902

# %%
# Metrics
evaluate(model, final_X_test, final_Y_test)
# Out:
# AUC score: 1.0
# PR score: 1.0
#
#
#
# TH - 0.5
# Precision: 0.9335076153671289
# Recall: 1.0
# F1score: 0.9656104873317265
# =============<>==================
#
# Confusion Matrix :
#  [[275635    585]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.93      1.00      0.97      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.97      1.00      0.98    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9989410614727392
# =============<>==================
#
#
#
#
# TH - 0.6
# Precision: 0.9447831588634533
# Recall: 1.0
# F1score: 0.9716077132379037
# =============<>==================
#
# Confusion Matrix :
#  [[275740    480]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.94      1.00      0.97      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.97      1.00      0.99    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9991311273622474
# =============<>==================
#
#
#
#
# TH - 0.7
# Precision: 0.9557779588036774
# Recall: 1.0
# F1score: 0.9773890277281924
# =============<>==================
#
# Confusion Matrix :
#  [[275840    380]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.96      1.00      0.98      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.98      1.00      0.99    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9993121424951126
# =============<>==================
#
#
#
#
# TH - 0.8
# Precision: 0.9641934726461611
# Recall: 1.0
# F1score: 0.981770366385751
# =============<>==================
#
# Confusion Matrix :
#  [[275915    305]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.96      1.00      0.98      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.98      1.00      0.99    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9994479038447613
# =============<>==================
#
#
#
#
# TH - 0.9
# Precision: 0.9693142924583973
# Recall: 1.0
# F1score: 0.9844180750329617
# =============<>==================
#
# Confusion Matrix :
#  [[275960    260]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.97      1.00      0.98      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.98      1.00      0.99    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9995293606545508
# =============<>==================
#
#
#
#
# TH - 1.0
# Precision: 0.9732195757791208
# Recall: 1.0
# F1score: 0.9864280566898872
# =============<>==================
#
# Confusion Matrix :
#  [[275994    226]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.97      1.00      0.99      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.99      1.00      0.99    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9995909057997249
# =============<>==================
#
#
#
#
# TH - 1.1
# Precision: 0.9764593984068481
# Recall: 1.0
# F1score: 0.9880895091434071
# =============<>==================
#
# Confusion Matrix :
#  [[276022    198]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.98      1.00      0.99      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.99      1.00      0.99    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9996415900369271
# =============<>==================
#
#
#
#
# TH - 1.2
# Precision: 0.9779709454632055
# Recall: 1.0
# F1score: 0.9888628017578713
# =============<>==================
#
# Confusion Matrix :
#  [[276035    185]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.98      1.00      0.99      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.99      1.00      0.99    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9996651220041995
# =============<>==================
#
#
#
#
# TH - 1.3
# Precision: 0.9803055621866794
# Recall: 1.0
# F1score: 0.990054849014526
# =============<>==================
#
# Confusion Matrix :
#  [[276055    165]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.98      1.00      0.99      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.99      1.00      0.99    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9997013250307726
# =============<>==================
#
#
#
#
# TH - 1.4
# Precision: 0.9821812963405884
# Recall: 1.0
# F1score: 0.9910105580693817
# =============<>==================
#
# Confusion Matrix :
#  [[276071    149]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.98      1.00      0.99      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.99      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.999730287452031
# =============<>==================
#
#
#
#
# TH - 1.5
# Precision: 0.983475032930188
# Recall: 1.0
# F1score: 0.9916686790630282
# =============<>==================
#
# Confusion Matrix :
#  [[276082    138]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.98      1.00      0.99      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.99      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9997501991166461
# =============<>==================
#
#
#
#
# TH - 1.75
# Precision: 0.9893988676063125
# Recall: 1.0
# F1score: 0.9946711880828387
# =============<>==================
#
# Confusion Matrix :
#  [[276132     88]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.99      1.00      0.99      8213
#
#     accuracy                           1.00    284433
#    macro avg       0.99      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9998407066830788
# =============<>==================
#
#
#
#
# TH - 2
# Precision: 0.991548955692382
# Recall: 1.0
# F1score: 0.9957565470417071
# =============<>==================
#
# Confusion Matrix :
#  [[276150     70]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.99      1.00      1.00      8213
#
#     accuracy                           1.00    284433
#    macro avg       1.00      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9998732894069945
# =============<>==================
#
#
#
#
# TH - 2.5
# Precision: 0.9945507386776459
# Recall: 1.0
# F1score: 0.997267925444721
# =============<>==================
#
# Confusion Matrix :
#  [[276175     45]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       0.99      1.00      1.00      8213
#
#     accuracy                           1.00    284433
#    macro avg       1.00      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9999185431902108
# =============<>==================
#
#
#
#
# TH - 2.75
# Precision: 0.9953944976366501
# Recall: 1.0
# F1score: 0.9976919339164236
# =============<>==================
#
# Confusion Matrix :
#  [[276182     38]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       1.00      1.00      1.00      8213
#
#     accuracy                           1.00    284433
#    macro avg       1.00      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9999312142495113
# =============<>==================
#
#
#
#
# TH - 3
# Precision: 0.9962396894711305
# Recall: 1.0
# F1score: 0.9981163030929088
# =============<>==================
#
# Confusion Matrix :
#  [[276189     31]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       1.00      1.00      1.00      8213
#
#     accuracy                           1.00    284433
#    macro avg       1.00      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9999438853088118
# =============<>==================
#
#
#
#
# TH - 3.25
# Precision: 0.9963605483440495
# Recall: 1.0
# F1score: 0.9981769567331066
# =============<>==================
#
# Confusion Matrix :
#  [[276190     30]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       1.00      1.00      1.00      8213
#
#     accuracy                           1.00    284433
#    macro avg       1.00      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9999456954601404
# =============<>==================
#
#
#
#
# TH - 3.5
# Precision: 0.9970863178341629
# Recall: 1.0
# F1score: 0.9985410334346504
# =============<>==================
#
# Confusion Matrix :
#  [[276196     24]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       1.00      1.00      1.00      8213
#
#     accuracy                           1.00    284433
#    macro avg       1.00      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.9999565563681123
# =============<>==================
#
#
#
#
# TH - 3.75
# Precision: 0.9972073822243808
# Recall: 1.0
# F1score: 0.9986017387075202
# =============<>==================
#
# Confusion Matrix :
#  [[276197     23]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       1.00      1.00      1.00      8213
#
#     accuracy                           1.00    284433
#    macro avg       1.00      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.999958366519441
# =============<>==================
#
#
#
#
# TH - 4
# Precision: 0.9975707518523017
# Recall: 1.0
# F1score: 0.9987838988203818
# =============<>==================
#
# Confusion Matrix :
#  [[276200     20]
#  [     0   8213]]
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    276220
#            1       1.00      1.00      1.00      8213
#
#     accuracy                           1.00    284433
#    macro avg       1.00      1.00      1.00    284433
# weighted avg       1.00      1.00      1.00    284433
#
# Area Under Curve :
#  0.999963796973427
# =============<>==================
